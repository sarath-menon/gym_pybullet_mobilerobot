# %%
import numpy as np
import pybullet as p
import time
import gym
import gym_pybullet_mobilerobot
from gym import spaces
from gym.utils import seeding

import os
import json
import random
import time
# import sys
# sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname(__file__))))
import torch
import torch.nn.functional as F
import gc
import torch.nn as nn
import math
from collections import deque
#---Directory Path---#
dirPath = os.path.dirname(os.path.realpath(__file__))
#---Functions to make network updates---#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-408bed522b53> in <module>()
#      20 from collections import deque
#      21 #---Directory Path---#
# ---> 22 dirPath = os.path.dirname(os.path.realpath(__file__))
#      23 #---Functions to make network updates---#
#
# NameError: name '__file__' is not defined

# %%
def soft_update(target, source, tau):
    for target_param, param in zip(target.parameters(), source.parameters()):
        target_param.data.copy_(target_param.data*(1.0 - tau)+ param.data*tau)

def hard_update(target,source):
    for target_param, param in zip(target.parameters(), source.parameters()):
        target_param.data.copy_(param.data)

#---Ornstein-Uhlenbeck Noise for action---#

class ActionNoise:
    # Based on http://math.stackexchange.com/questions/1287634/implementing-ornstein-uhlenbeck-in-matlab
    def __init__(self, action_dim, mu=0, theta=0.15, sigma=0.2):
        self.action_dim = action_dim
        self.mu = mu
        self.theta = theta
        self.sigma = sigma
        self.X = np.ones(self.action_dim)*self.mu

    def reset(self):
        self.X = np.ones(self.action_dim)*self.mu

    def sample(self):
        dx = self.theta*(self.mu - self.X)
        dx = dx + self.sigma*np.random.randn(len(self.X))
        self.X = self.X + dx
        print('aqu2i' + str(self.X))
        return self.X

#---Critic--#

EPS = 0.003
def fanin_init(size, fanin=None):
    fanin = fanin or size[0]
    v = 1./np.sqrt(fanin)
    return torch.Tensor(size).uniform_(-v,v)

class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        self.state_dim = state_dim = state_dim
        self.action_dim = action_dim

        self.fc1 = nn.Linear(state_dim, 256)
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())

        self.fa1 = nn.Linear(action_dim, 256)
        self.fa1.weight.data = fanin_init(self.fa1.weight.data.size())

        self.fca1 = nn.Linear(512, 512)
        self.fca1.weight.data = fanin_init(self.fca1.weight.data.size())

        self.fca2 = nn.Linear(512, 1)
        self.fca2.weight.data.uniform_(-EPS, EPS)

    def forward(self, state, action):
        xs = torch.relu(self.fc1(state))
        xa = torch.relu(self.fa1(action))
        x = torch.cat((xs,xa), dim=1)
        x = torch.relu(self.fca1(x))
        vs = self.fca2(x)
        return vs

#---Actor---#

class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, action_limit_v, action_limit_w):
        super(Actor, self).__init__()
        self.state_dim = state_dim = state_dim
        self.action_dim = action_dim
        self.action_limit_v = action_limit_v
        self.action_limit_w = action_limit_w

        self.fa1 = nn.Linear(state_dim, 512)
        self.fa1.weight.data = fanin_init(self.fa1.weight.data.size())

        self.fa2 = nn.Linear(512, 512)
        self.fa2.weight.data = fanin_init(self.fa2.weight.data.size())

        self.fa3 = nn.Linear(512, action_dim)
        self.fa3.weight.data.uniform_(-EPS,EPS)

    def forward(self, state):
        x = torch.relu(self.fa1(state))
        x = torch.relu(self.fa2(x))
        action = self.fa3(x)
        if state.shape == torch.Size([14]):
            action[0] = torch.sigmoid(action[0])*self.action_limit_v
            action[1] = torch.tanh(action[1])*self.action_limit_w
        else:
            action[:,0] = torch.sigmoid(action[:,0])*self.action_limit_v
            action[:,1] = torch.tanh(action[:,1])*self.action_limit_w
        return action

#---Memory Buffer---#

class MemoryBuffer:
    def __init__(self, size):
        self.buffer = deque(maxlen=size)
        self.maxSize = size
        self.len = 0

    def sample(self, count):
        batch = []
        count = min(count, self.len)
        batch = random.sample(self.buffer, count)

        s_array = np.float32([array[0] for array in batch])
        a_array = np.float32([array[1] for array in batch])
        r_array = np.float32([array[2] for array in batch])
        new_s_array = np.float32([array[3] for array in batch])

        return s_array, a_array, r_array, new_s_array

    def len(self):
        return self.len

    def add(self, s, a, r, new_s):
        transition = (s, a, r, new_s)
        self.len += 1
        if self.len > self.maxSize:
            self.len = self.maxSize
        self.buffer.append(transition)

# %%
#---Where the train is made---#

BATCH_SIZE = 128
LEARNING_RATE = 0.001
GAMMA = 0.99
TAU = 0.001

class Trainer:

    def __init__(self, state_dim, action_dim, action_limit_v, action_limit_w, ram):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.action_limit_v = action_limit_v
        self.action_limit_w = action_limit_w
        #print('w',self.action_limit_w)
        self.ram = ram
        #self.iter = 0
        self.noise = ActionNoise(self.action_dim)

        self.actor = Actor(self.state_dim, self.action_dim, self.action_limit_v, self.action_limit_w)
        self.target_actor = Actor(self.state_dim, self.action_dim, self.action_limit_v, self.action_limit_w)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), LEARNING_RATE)

        self.critic = Critic(self.state_dim, self.action_dim)
        self.target_critic = Critic(self.state_dim, self.action_dim)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), LEARNING_RATE)

        hard_update(self.target_actor, self.actor)
        hard_update(self.target_critic, self.critic)

    def get_exploitation_action(self,state):
        state = torch.from_numpy(state)
        action = self.target_actor.forward(state).detach()
        #print('actionploi', action)
        return action.data.numpy()

    def get_exploration_action(self, state):
        state = torch.from_numpy(state)
        action = self.actor.forward(state).detach()
        #noise = self.noise.sample()
        #print('noisea', noise)
        #noise[0] = noise[0]*self.action_limit_v
        #noise[1] = noise[1]*self.action_limit_w
        #print('noise', noise)
        new_action = action.data.numpy() #+ noise
        #print('action_no', new_action)
        return new_action

    def optimizer(self):
        s_sample, a_sample, r_sample, new_s_sample = ram.sample(BATCH_SIZE)

        s_sample = torch.from_numpy(s_sample)
        a_sample = torch.from_numpy(a_sample)
        r_sample = torch.from_numpy(r_sample)
        new_s_sample = torch.from_numpy(new_s_sample)

        #-------------- optimize critic

        a_target = self.target_actor.forward(new_s_sample).detach()
        next_value = torch.squeeze(self.target_critic.forward(new_s_sample, a_target).detach())
        # y_exp = r _ gamma*Q'(s', P'(s'))
        y_expected = r_sample + GAMMA*next_value
        # y_pred = Q(s,a)
        y_predicted = torch.squeeze(self.critic.forward(s_sample, a_sample))

        #----------------------------
        loss_critic = F.smooth_l1_loss(y_predicted, y_expected)

        self.critic_optimizer.zero_grad()
        loss_critic.backward()
        self.critic_optimizer.step()

        #------------ optimize actor
        pred_a_sample = self.actor.forward(s_sample)
        loss_actor = -1*torch.sum(self.critic.forward(s_sample, pred_a_sample))

        self.actor_optimizer.zero_grad()
        loss_actor.backward()
        self.actor_optimizer.step()

        soft_update(self.target_actor, self.actor, TAU)
        soft_update(self.target_critic, self.critic, TAU)

    def save_models(self, episode_count):
        torch.save(self.target_actor.state_dict(), '/Users/sarathmenon/Downloads/TD3-master/project_exp_models/'+str(episode_count)+'_actor.pt')
        torch.save(self.target_critic.state_dict(), '/Users/sarathmenon/Downloads/TD3-master/project_exp_models/'+str(episode_count)+'_critic.pt')
        print('****Models saved***')

    def load_models(self, episode_count):
        self.actor.load_state_dict(torch.load('/Users/sarathmenon/Downloads/TD3-master/project_exp_models/'+str(episode_count)+'_actor.pt'))
        self.critic.load_state_dict(torch.load('/Users/sarathmenon/Downloads/TD3-master/project_exp_models/'+str(episode_count)+'_critic.pt'))
        hard_update(self.target_actor, self.actor)
        hard_update(self.target_critic, self.critic)
        print('***Models load***')

#---Run agent---#

is_training = True

if is_training:
    exploration_rate = 1
    max_exploration_rate = 1
    min_exploration_rate = 0.05
else:
    exploration_rate = 0.05
    max_exploration_rate = 0.05
    min_exploration_rate = 0.05

exploration_decay_rate = 0.001

MAX_EPISODES = 10001
MAX_STEPS = 1000          # Important parameter
MAX_BUFFER = 100000
rewards_all_episodes = []

STATE_DIMENSION = 14
ACTION_DIMENSION = 2
ACTION_V_MAX = 2.0 # m/s
ACTION_W_MAX = 1.0# rad/s

if is_training:
    var_v = ACTION_V_MAX*0.20
    var_w = ACTION_W_MAX*2*0.20
else:
    var_v = ACTION_V_MAX*0.10
    var_w = ACTION_W_MAX*0.10

print('State Dimensions: ' + str(STATE_DIMENSION))
print('Action Dimensions: ' + str(ACTION_DIMENSION))
print('Action Max: ' + str(ACTION_V_MAX) + ' m/s and ' + str(ACTION_W_MAX) + ' rad/s')
ram = MemoryBuffer(MAX_BUFFER)
trainer = Trainer(STATE_DIMENSION, ACTION_DIMENSION, ACTION_V_MAX, ACTION_W_MAX, ram)
episode_count = 160
trainer.load_models(episode_count)
# Out:
# State Dimensions: 14
# Action Dimensions: 2
# Action Max: 2.0 m/s and 1.0 rad/s
# ***Models load***

# %%
if __name__ == '__main__':
    env = gym.make("Mobilerobot_Pybullet-v0")

    start_time = time.time()
    past_action = np.array([0.,0.])

    for ep in range(MAX_EPISODES):
        ep+=episode_count
        done = False
        state = env.reset()
        print('Episode: ' + str(ep))

        rewards_current_episode = 0
        for step in range(MAX_STEPS):
            #print(step)
            state = np.float32(state)
            #action = trainer.get_exploration_action(state)
            #print('actionA:', action)

            #action[0] = np.clip(np.random.normal(action[0], var_v), 0., ACTION_V_MAX)
            #action[1] = np.clip(np.random.normal(action[1], var_w), -ACTION_W_MAX, ACTION_W_MAX)
            #print('actionD', action)

            if is_training:
                #if ep%2 == 0:
                #    action = trainer.get_exploitation_action(state)
                #    #print('aa', action)
                #else:
                action = trainer.get_exploration_action(state)
                #    #print('aa',action)
                action[0] = np.clip(np.random.normal(action[0], var_v), 0., ACTION_V_MAX)
                action[1] = np.clip(np.random.normal(action[1], var_w), -ACTION_W_MAX, ACTION_W_MAX)
                #action[0] = np.clip(action[0], 0., ACTION_V_MAX)
                #action[1] = np.clip(action[1], -ACTION_W_MAX, ACTION_W_MAX)
            #print('af', action)

            #exploration_rate_threshold = random.uniform(0., 1.)
            #if exploration_rate_threshold > exploration_rate:
            #    action = trainer.get_exploration_action(state)
            #else:
            #    action = np.array([np.random.uniform(0,0.22), np.random.uniform(-1,1)])

            if not is_training:
                #print('nor')
                action = trainer.get_exploitation_action(state)
            #print('state',state)
            #print('action',action)
            #print('ap',past_action)
            print('Linear:',action[0],'Angular:',action[1])
            action = env.differential_drive(action)
            next_state, reward, done, _ = env.step(action)#, past_action)
            print('episode_count:',ep,'action', action,'r',reward)
            # past_action = action

            rewards_current_episode += reward
            next_state = np.float32(next_state)
            ram.add(state, action, reward, next_state)
            state = next_state

            #action = np.array([np.random.uniform(0.,0.15), np.random.uniform(-0.5, 0.5)])
            #print('r: ' + str(reward) + ' and done: ' + str(done))

            if ram.len >= 2*MAX_STEPS and is_training:
                var_v = max([var_v*0.99999, 0.10*ACTION_V_MAX])
                var_w = max([var_w*0.99999, 0.10*ACTION_W_MAX])
                trainer.optimizer()
            #if is_training:
            #    trainer.optimizer()

            if done or step == MAX_STEPS-1:
                print('reward per ep: ' + str(rewards_current_episode))
                print('explore_v: ' + str(var_v) + ' and explore_w: ' + str(var_w))
                rewards_all_episodes.append(rewards_current_episode)
                m, s = divmod(int(time.time() - start_time), 60)
                h, m = divmod(m, 60)
                break
        exploration_rate = (min_exploration_rate +
                (max_exploration_rate - min_exploration_rate)* np.exp(-exploration_decay_rate*ep))
        gc.collect()
        #print('exp:', exploration_rate)
        if ep%10 == 0:
            trainer.save_models(ep)

print('Completed Training')
# Out:
# 1234: /Users/sarathmenon/Downloads/gym_pybullet_mobilerobot/gym_pybullet_mobilerobot/envs/data/wall.urdf
# Episode: 160
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r 393.49164787025705
# Linear: 0.0 Angular: -0.63662535
# yes
# episode_count: 160 action [-6.3662535  6.3662535] r -8.0
# Linear: 0.5364777 Angular: -0.4131098
# yes
# episode_count: 160 action [1.23367876 9.49587464] r -8.0
# Linear: 0.04231024 Angular: -1.0
# yes
# episode_count: 160 action [-9.57689762 10.42310238] r -8.0
# Linear: 0.5222706 Angular: -1.0
# yes
# episode_count: 160 action [-4.7772938  15.22270679] r -8.0
# Linear: 0.031041699 Angular: -1.0
# yes
# episode_count: 160 action [-9.68958318 10.31041741] r -8.0
# Linear: 0.44213066 Angular: -0.54430366
# yes
# episode_count: 160 action [-1.02173001  9.8643434 ] r -8.0
# Linear: 0.5875429 Angular: -1.0
# yes
# episode_count: 160 action [-4.12457108 15.87542892] r -8.0
# Linear: 0.16075706 Angular: -0.3447336
# yes
# episode_count: 160 action [-1.83976531  5.05490661] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -0.70802385
# yes
# episode_count: 160 action [-7.08023846  7.08023846] r 0.02517564846162834
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r 0.14868927398392628
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.]
r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.04433468 Angular: -0.4396503
# yes
# episode_count: 160 action [-3.95315617  4.83984977] r -8.0
# Linear: 0.0 Angular: 0.40671295
# yes
# episode_count: 160 action [ 4.06712949 -4.06712949] r -8.0
# Linear: 0.48222825 Angular: 0.28524023
# yes
# episode_count: 160 action [7.67468452 1.96988016] r -8.0
# Linear: 0.13018271 Angular: 0.3104731
# yes
# episode_count: 160 action [ 4.40655828 -1.80290401] r -8.0
# Linear: 0.4524165 Angular: 0.26834038
# yes
# episode_count: 160 action [7.20756888 1.8407613 ] r -8.0
# Linear: 0.19333874 Angular: -0.16766079
# yes
# episode_count: 160 action [0.25677949 3.60999525] r -8.0
# Linear: 0.04407255 Angular: 0.5273372
# yes
# episode_count: 160 action [ 5.71409762 -4.83264655] r -8.0
# Linear: 0.049188524 Angular: 0.67782915
# yes
# episode_count: 160 action [ 7.27017641 -6.28640652] r -8.0
# Linear: 0.0 Angular: 0.648732
# yes
# episode_count: 160 action [ 6.48732007 -6.48732007] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.8888173 Angular: 0.7679982
# yes
# episode_count: 160 action [16.56815529  1.20819092] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.2586388 Angular: -0.29548675
# yes
# episode_count: 160 action [-0.36847949  5.54125547] r -8.0
# Linear: 0.0 Angular: -0.9521516
# yes
# episode_count: 160 action [-9.52151597  9.52151597] r -8.0
# Linear: 0.102637544 Angular: -1.0
# yes
# episode_count: 160 action [-8.97362471 11.02637529] r -8.0
# Linear: 0.7701449 Angular: -0.5906911
# yes
# episode_count: 160 action [ 1.7945379  13.60836029] r -8.0
# Linear: 0.4236473 Angular: -1.0
# yes
# episode_count: 160 action [-5.76352715 14.23647285] r -8.0
# Linear: 0.55406296 Angular: -1.0
# yes
# episode_count: 160 action [-4.45937037 15.54062963] r -8.0
# Linear: 0.05441196 Angular: -0.03272038
# yes
# episode_count: 160 action [0.21691579 0.87132335] r -8.0
# Linear: 0.6246852 Angular: -0.82763666
# yes
# episode_count: 160 action [-2.02951431 14.52321887] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.20935087 Angular: -1.0
# yes
# episode_count: 160 action [-7.90649116 12.09350824] r -8.0
# Linear: 0.4530891 Angular: -1.0
# yes
# episode_count: 160 action [-5.46910882 14.53089118] r -8.0
# Linear: 0.011778595 Angular: -0.6850899
# yes
# episode_count: 160 action [-6.73311293  6.96868479] r -8.0
# Linear: 0.0 Angular: -0.14474428
# yes
# episode_count: 160 action [-1.44744277  1.44744277] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.29971004 Angular: 0.18637097
# yes
# episode_count: 160 action [4.86081004 1.13339067] r -8.0
# Linear: 0.15848036 Angular: 1.0
# yes
# episode_count: 160 action [11.58480406 -8.41519654] r -8.0
# Linear: 0.0 Angular: 0.38318053
# yes
# episode_count: 160 action [ 3.83180529 -3.83180529] r -8.0
# Linear: 0.34022442 Angular: 0.4665545
# yes
# episode_count: 160 action [ 8.06778908 -1.26330078] r -8.0
# Linear: 0.25205567 Angular: 0.6236758
# yes
# episode_count: 160 action [ 8.75731468 -3.71620148] r -8.0
# Linear: 0.46455878 Angular: 0.45939797
# yes
# episode_count: 160 action [-6.04688287  6.04688287] r -8.0
# Linear: 0.0 Angular: 0.046606712
# yes
# episode_count: 160 action [ 0.46606712 -0.46606712] r -8.0
# Linear: 0.5125793 Angular: -0.18750508
# yes
# episode_count: 160 action [3.25074255 7.00084388] r -8.0
# Linear: 0.0 Angular: -0.51210445
# yes
# episode_count: 160 action [-5.12104452  5.12104452] r -8.0
# Linear: 0.0 Angular: -0.14043929
# yes
# episode_count: 160 action [-1.40439287  1.40439287] r -8.0
# Linear: 0.0 Angular: 0.5210485
# yes
# episode_count: 160 action [ 5.21048486 -5.21048486] r -8.0
# Linear: 0.16834296 Angular: -0.13948756
# yes
# episode_count: 160 action [0.28855398 3.07830513] r -8.0
# Linear: 0.19955483 Angular: 0.7413203
# yes
# episode_count: 160 action [ 9.40875173 -5.41765451] r -8.0
# Linear: 0.28660485 Angular: -0.015461299
# yes
# episode_count: 160 action [2.71143556 3.02066147] r -8.0
# Linear: 0.0 Angular: -0.1335939
# yes
# episode_count: 160 action [-1.33593902  1.33593902] r -8.0
# Linear: 0.261936 Angular: 0.57298213
# yes
# episode_count: 160 action [ 8.34918141 -3.11046124] r -8.0
# Linear: 1.1773764 Angular: 0.37094533
# yes
# episode_count: 160 action [15.48321724  8.06431055] r -8.0
# Linear: 0.2113329 Angular: 0.49439093
# yes
# episode_count: 160 action [ 7.05723822 -2.83058047] r -8.0
# Linear: 0.2880922 Angular: 0.5709767
# yes
# episode_count: 160 action [ 8.59068871 -2.82884479] r -8.0
# Linear: 0.3120763 Angular: 0.075450405
# yes
# episode_count: 160 action [3.87526691 2.36625895] r -8.0
# Linear: 0.0 Angular: 0.16177098
# yes
# episode_count: 160 action [ 1.61770985 -1.61770985] r -8.0
# Linear: 0.21557537 Angular: 0.6414187
# yes
# episode_count: 160 action [ 8.56994033 -4.25843328] r -8.0
# Linear: 0.04541639 Angular: 0.36655158
# yes
# episode_count: 160 action [ 4.11967963 -3.21135193] r -8.0
# Linear: 0.9042199 Angular: 0.8082356
# yes
# episode_count: 160 action [17.12455511  0.9598434 ] r -8.0
# Linear: 0.40933168 Angular: 1.0
# yes
# episode_count: 160 action [14.09331679 -5.90668321] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.08948752 Angular: 1.0
# yes
# episode_count: 160 action [10.89487553 -9.10512447] r -8.0
# Linear: 0.09409005 Angular: 0.85075176
# yes
# episode_count: 160 action [ 9.44841802 -7.56661713] r -8.0
# Linear: 0.0 Angular: -0.8218673
# yes
# episode_count: 160 action [-8.21867287  8.21867287] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.6106279 Angular: -1.0
# yes
# episode_count: 160 action [-3.8937211 16.1062789] r -8.0
# Linear: 0.0 Angular: -0.85122806
# yes
# episode_count: 160 action [-8.51228058  8.51228058] r 0.01854375737302405
# Linear: 0.2551183 Angular: -1.0
# yes
# episode_count: 160 action [-7.4488169 12.5511837] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.33312088 Angular: -1.0
# yes
# episode_count: 160 action [-6.66879117 13.33120823] r -8.0
# Linear: 0.35288987 Angular: 0.23800644
# yes
# episode_count: 160 action [5.90896308 1.14883423] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.6624095
# yes
# episode_count: 160 action [ 6.62409484 -6.62409484] r -8.0
# Linear: 0.0 Angular: 0.91884935
# yes
# episode_count: 160 action [ 9.18849349 -9.18849349] r -8.0
# Linear: 0.0 Angular: 0.93162197
# yes
# episode_count: 160 action [ 9.31621969 -9.31621969] r -8.0
# Linear: 0.0 Angular: 0.94239026
# yes
# episode_count: 160 action [ 9.42390263 -9.42390263] r -8.0
# Linear: 1.1798671 Angular: 0.50718766
# yes
# episode_count: 160 action [16.87054873  6.72679484] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.68121696
# yes
# episode_count: 160 action [ 6.81216955 -6.81216955] r -8.0
# Linear: 0.0 Angular: 0.46443254
# yes
# episode_count: 160 action [ 4.64432538 -4.64432538] r -8.0
# Linear: 0.7945466 Angular: 1.0
# yes
# episode_count: 160 action [17.94546604 -2.05453396] r -8.0
# Linear: 0.061832502 Angular: 0.910667
# yes
# episode_count: 160 action [ 9.7249949  -8.48834515] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.91603017 Angular: 0.67948186
# yes
# episode_count: 160 action [15.95512033  2.36548305] r -8.0
# Linear: 0.11140157 Angular: -0.19375001
# yes
# episode_count: 160 action [-0.82348436  3.05151582] r -8.0
# Linear: 0.19118288 Angular: -0.5621532
# yes
# episode_count: 160 action [-3.70970339  7.53336072] r -8.0
# Linear: 0.0 Angular: -0.6754219
# yes
# episode_count: 160 action [-6.75421894  6.75421894] r -8.0
# Linear: 0.7626821 Angular: -0.50300646
# yes
# episode_count: 160 action [ 2.59675622 12.65688539] r -8.0
# Linear: 0.27108642 Angular: -1.0
# yes
# episode_count: 160 action [-7.28913546 12.71086454] r -8.0
# Linear: 0.16157193 Angular: -0.80742985
# yes
# episode_count: 160 action [-6.4585793  9.6900177] r -8.0
# Linear: 0.41997784 Angular: -0.85776216
# yes
# episode_count: 160 action [-4.37784314 12.77740002] r -8.0
# Linear: 0.005555819 Angular: -0.85967255
# yes
# episode_count: 160 action [-8.54116738  8.65228355] r -8.0
# Linear: 0.020785632 Angular: -1.0
# yes
# episode_count: 160 action [-9.7921437  10.20785689] r 0.06170372125580137
# Linear: 0.0 Angular: 0.44668368
# yes
# episode_count: 160 action [ 4.46683675 -4.46683675] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.24017611 Angular: 0.85040027
# yes
# episode_count: 160 action [10.9057641  -6.10224128] r -8.0
# Linear: 0.5017725 Angular: 0.89114803
# yes
# episode_count: 160 action [13.92920494 -3.89375508] r 0.037033708287959044
# Linear: 0.0 Angular: 0.92552865
# yes
# episode_count: 160 action [ 9.25528646 -9.25528646] r 0.0534674849504313
# Linear: 0.0 Angular: 0.55896574
# yes
# episode_count: 160 action [ 5.58965743 -5.58965743] r 0.043452726109105555
# Linear: 0.0 Angular: 0.56374484
# yes
# episode_count: 160 action [ 5.63744843 -5.63744843] r -8.0
# Linear: 0.31054276 Angular: 0.80429393
# yes
# episode_count: 160 action [11.14836693 -4.93751168] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.]
# Linear: 0.13226588 Angular: -1.0
# yes
# episode_count: 160 action [-8.67734134 11.32265925] r -8.0
# Linear: 0.0 Angular: -0.665207
# yes
# episode_count: 160 action [-6.65207028  6.65207028] r -8.0
# Linear: 0.047640685 Angular: 0.634092
# yes
# episode_count: 160 action [ 6.81732655 -5.86451292] r 0.004657338281699452
# Linear: 0.98054427 Angular: 1.0
# yes
# episode_count: 160 action [19.80544329 -0.19455731] r -8.0
# Linear: 0.093170494 Angular: 1.0
# yes
# episode_count: 160 action [10.93170524 -9.06829476] r 0.019448790232168278
# Linear: 0.0 Angular: 0.0631094
# yes
# episode_count: 160 action [ 0.63109398 -0.63109398] r -8.0
# Linear: 0.0 Angular: 0.80392593
# yes
# episode_count: 160 action [ 8.03925931 -8.03925931] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.667252 Angular: 1.0
# yes
# episode_count: 160 action [16.67252064 -3.32747996] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.066111475 Angular: 1.0
# yes
# episode_count: 160 action [10.66111445 -9.33888555] r 0.027712981589367303
# Linear: 0.5515549 Angular: -0.17595953
# yes
# episode_count: 160 action [3.75595391 7.27514446] r -8.0
# Linear: 0.0 Angular: -0.77050495
# yes
# episode_count: 160 action [-7.70504951  7.70504951] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.13052318 Angular: -0.69958323
# yes
# episode_count: 160 action [-5.69060087  8.30106378] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -0.8417781
# yes
# episode_count: 160 action [-8.417781  8.417781] r -8.0
# Linear: 0.0 Angular: -0.7391205
# yes
# episode_count: 160 action [-7.39120483  7.39120483] r -8.0
# Linear: 0.0 Angular: -0.9456107
# yes
# episode_count: 160 action [-9.45610702  9.45610702] r 0.02069127387254177
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.42113155 Angular: 1.0
# yes
# episode_count: 160 action [14.21131611 -5.78868449] r -8.0
# Linear: 0.01795759 Angular: 1.0
# yes
# episode_count: 160 action [10.17957568 -9.82042432] r -8.0
# Linear: 0.0 Angular: 0.99322087
# yes
# episode_count: 160 action [ 9.93220866 -9.93220866] r -8.0
# Linear: 1.0226514 Angular: 1.0
# yes
# episode_count: 160 action [20.22651434  0.22651434] r -8.0
# Linear: 0.0 Angular: 0.19856913
# yes
# episode_count: 160 action [ 1.98569134 -1.98569134] r -8.0
# Linear: 0.0 Angular: 0.1752138
# yes
# episode_count: 160 action [ 1.75213799 -1.75213799] r -8.0
# Linear: 0.86088794 Angular: -0.06676141
# yes
# episode_count: 160 action [7.94126511 9.27649379] r -8.0
# Linear: 0.35555354 Angular: -0.12634811
# yes
# episode_count: 160 action [2.2920543  4.81901646] r -8.0
# Linear: 0.85531837 Angular: 0.6373122
# yes
# episode_count: 160 action [14.92630482  2.18006194] r -8.0
# Linear: 0.14482127 Angular: 0.9931261
# yes
# episode_count: 160 action [11.37947321 -8.48304808] r -8.0
# Linear: 0.6085456 Angular: 1.0
# yes
# episode_count: 160 action [16.08545542 -3.91454399] r -8.0
# Linear: 0.0 Angular: 0.50528866
# yes
# episode_count: 160 action [ 5.05288661 -5.05288661] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.31025288 Angular: 1.0
# yes
# episode_count: 160 action [13.10252905 -6.89747095] r -8.0
# Linear: 0.15394528 Angular: 0.6886412
# yes
# episode_count: 160 action [ 8.42586458 -5.34695923] r -8.0
# Linear: 0.0 Angular: 0.9197094
# yes
# episode_count: 160 action [ 9.19709384 -9.19709384] r -8.0
# Linear: 0.123684324 Angular: -1.0
# yes
# episode_count: 160 action [-8.76315653 11.23684287] r -8.0
# Linear: 0.0 Angular: -0.9681646
# yes
# episode_count: 160 action [-9.68164623  9.68164623] r -8.0
# Linear: 0.5389355 Angular: -0.9711072
# yes
# episode_count: 160 action [-4.32171702 15.10042667] r -8.0
# Linear: 0.0 Angular: -0.8161206
# yes
# episode_count: 160 action [-8.16120625  8.16120625] r 0.05432286933060304
# Linear: 0.723833 Angular: -0.33316004
# yes
# episode_count: 160 action [ 3.90672982 10.56993008] r -8.0
# Linear: 0.4168896 Angular: -1.0
# yes
# episode_count: 160 action [-5.83110392 14.16889668] r -8.0
# Linear: 0.099944144 Angular: -1.0
# yes
# episode_count: 160 action [-9.00055885 10.99944115] r -8.0
# Linear: 0.83634055 Angular: -0.8672761
# yes
# episode_count: 160 action [-0.30935526 17.03616619] r -8.0
# Linear: 0.1705892 Angular: 0.7801049
# yes
# episode_count: 160 action [ 9.50694084 -6.09515667] r -8.0
# Linear: 0.0 Angular: 0.7844311
# yes
# episode_count: 160 action [ 7.844311 -7.844311] r -8.0
# Linear: 0.0 Angular: 0.30085367
# yes
# episode_count: 160 action [ 3.0085367 -3.0085367] r -8.0
# Linear: 0.1456102 Angular: 0.9635201
# yes
# episode_count: 160 action [11.09130263 -8.17909896] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.86992896 Angular: 1.0
# yes
# episode_count: 160 action [18.69928956 -1.30071044] r -8.0
# Linear: 0.14961657 Angular: 0.86392736
# yes
# episode_count: 160 action [10.13543963 -7.14310765] r -8.0
# Linear: 0.0 Angular: 0.5913142
# yes
# episode_count: 160 action [ 5.91314197 -5.91314197] r -8.0
# Linear: 0.51603955 Angular: 1.0
# yes
# episode_count: 160 action [15.1603961 -4.8396045] r -8.0
# Linear: 0.572292 Angular: 0.8848452
# yes
# episode_count: 160 action [14.57137108 -3.12553227] r -8.0
# Linear: 0.4049466 Angular: 0.65482455
# yes
# episode_count: 160 action [10.5977118  -2.49877959] r -8.0
# Linear: 0.2487512 Angular: -1.0
# yes
# episode_count: 160 action [-7.51248837 12.48751163] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.5759193 Angular: -0.83516175
# yes
# episode_count: 160 action [-2.59242475 14.11081076] r -8.0
# Linear: 0.2429262 Angular: -0.98485214
# yes
# episode_count: 160 action [-7.41925955 12.27778316] r -8.0
# Linear: 0.0 Angular: -0.69061613
# yes
# episode_count: 160 action [-6.90616131  6.90616131] r -8.0
# Linear: 0.50260454 Angular: -0.490013
# yes
# episode_count: 160 action [0.12591541 9.92617548] r -8.0
# Linear: 0.0 Angular: 0.18707682
# yes
# episode_count: 160 action [ 1.87076822 -1.87076822] r -8.0
# Linear: 0.0 Angular: 0.46402693
# yes
# episode_count: 160 action [ 4.64026928 -4.64026928] r -8.0
# Linear: 0.05395833 Angular: 1.0
# yes
# episode_count: 160 action [10.53958297 -9.46041644] r -8.0
# Linear: 0.40942147 Angular: 1.0
# yes
# episode_count: 160 action [14.09421444 -5.90578556]
r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.6108949
# yes
# episode_count: 160 action [ 6.10894918 -6.10894918] r -8.0
# Linear: 0.38100988 Angular: 1.0
# yes
# episode_count: 160 action [13.81009817 -6.18990123] r -8.0
# Linear: 0.5651769 Angular: 0.44820702
# yes
# episode_count: 160 action [10.13383865  1.16969883] r -8.0
# Linear: 0.0 Angular: 0.42922857
# yes
# episode_count: 160 action [ 4.29228574 -4.29228574] r -8.0
# Linear: 0.2480566 Angular: 0.119796
# yes
# episode_count: 160 action [3.67852598 1.28260612] r -8.0
# Linear: 0.37892455 Angular: -1.0
# yes
# episode_count: 160 action [-6.21075451 13.78924608] r -8.0
# Linear: 0.3306671 Angular: 0.908112
# yes
# episode_count: 160 action [12.38779068 -5.77444911] r -8.0
# Linear: 0.0 Angular: -0.5566562
# yes
# episode_count: 160 action [-5.56656182  5.56656182] r -8.0
# Linear: 0.1353236 Angular: -1.0
# yes
# episode_count: 160 action [-8.64676416 11.35323644] r -8.0
# Linear: 0.74692005 Angular: -0.8836734
# yes
# episode_count: 160 action [-1.3675338  16.30593538] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.53860825 Angular: 1.0
# yes
# episode_count: 160 action [15.38608313 -4.61391747] r -8.0
# Linear: 0.0 Angular: 0.89737517
# yes
# episode_count: 160 action [ 8.97375166 -8.97375166] r -8.0
# Linear: 0.20383364 Angular: 1.0
# yes
# episode_count: 160 action [12.0383358 -7.9616636] r -8.0
# Linear: 0.0 Angular: 0.11080842
# yes
# episode_count: 160 action [ 1.10808417 -1.10808417] r -8.0
# Linear: 0.37191716 Angular: -0.9048216
# yes
# episode_count: 160 action [-5.32904387 12.76738763] r -8.0
# Linear: 0.4749744 Angular: -1.0
# yes
# episode_count: 160 action [-5.25025606 14.74974394] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -0.924378
# yes
# episode_count: 160 action [-9.24377978  9.24377978] r 0.026556376219932787
# Linear: 0.35077125 Angular: 0.6559384
# yes
# episode_count: 160 action [10.06709576 -3.05167139] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.042804282 Angular: 1.0
# yes
# episode_count: 160 action [10.42804241 -9.57195699] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.54219836 Angular: 0.9830928
# yes
# episode_count: 160 action [15.25291204 -4.40894425] r 0.03278867290363863
# Linear: 0.0 Angular: 0.90327173
# yes
# episode_count: 160 action [ 9.03271735 -9.03271735] r 0.111313200126828
# Linear: 0.32618144 Angular: 0.74744296
# yes
# episode_count: 160 action [10.73624372 -4.21261519] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.28496113 Angular: 0.08951629
# yes
# episode_count: 160 action [3.74477416 1.95444852] r 0.07510890718047669
# Linear: 0.0 Angular: -0.42267734
# yes
# episode_count: 160 action [-4.22677338  4.22677338] r 0.06164634583138984
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r 0.06733335959401288
# Linear: 0.0 Angular: -0.60902804
# yes
# episode_count: 160 action [-6.09028041  6.09028041] r 0.06118700939885535
# Linear: 0.5960559 Angular: -1.0
# yes
# episode_count: 160 action [-4.03944075 15.96055984] r -8.0
# Linear: 0.0 Angular: 0.40568584
# yes
# episode_count: 160 action [ 4.05685842 -4.05685842] r -8.0
# Linear: 0.0 Angular: 0.78214544
# yes
# episode_count: 160 action [ 7.82145441 -7.82145441] r -8.0
# Linear: 0.07472743 Angular: 0.24436927
# yes
# episode_count: 160 action [ 3.19096684 -1.69641837] r -8.0
# Linear: 0.0 Angular: 0.723811
# yes
# episode_count: 160 action [ 7.23810971 -7.23810971] r -8.0
# Linear: 0.5444118 Angular: 0.7716899
# yes
# episode_count: 160 action [13.1610167  -2.27278113] r -8.0
# Linear: 0.0 Angular: 0.46798784
# yes
# episode_count: 160 action [ 4.67987835 -4.67987835] r -8.0
# Linear: 0.08659959 Angular: -1.0
# yes
# episode_count: 160 action [-9.13400412 10.86599588] r -8.0
# Linear: 0.5012968 Angular: -1.0
# yes
# episode_count: 160 action [-4.98703182 15.01296759] r -8.0
# Linear: 0.0 Angular: -0.784501
# yes
# episode_count: 160 action [-7.84501016  7.84501016] r 0.03330398663603518
# Linear: 0.84509915 Angular: -1.0
# yes
# episode_count: 160 action [-1.54900849 18.45099211] r -8.0
# Linear: 0.16537032 Angular: -0.6320637
# yes
# episode_count: 160 action [-4.66693372  7.97433972] r -8.0
# Linear: 0.41652307 Angular: 0.81061536
# yes
# episode_count: 160 action [12.271384   -3.94092292] r -8.0
# Linear: 0.30848873 Angular: 1.0
# yes
# episode_count: 160 action [13.08488727 -6.91511273] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.6572319 Angular: 1.0
# yes
# episode_count: 160 action [16.57231927 -3.42768073] r -8.0
# Linear: 0.4606911 Angular: 0.8965017
# yes
# episode_count: 160 action [13.57192755 -4.35810626] r -8.0
# Linear: 0.5771281 Angular: -1.0
# yes
# episode_count: 160 action [-4.22871888 15.77128172] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.31217784 Angular: -0.45576534
# yes
# episode_count: 160 action [-1.435875    7.67943144] r -8.0
# Linear: 0.0 Angular: -0.728355
# yes
# episode_count: 160 action [-7.2835499  7.2835499] r -8.0
# Linear: 0.18914442 Angular: -0.38402838
# yes
# episode_count: 160 action [-1.94883958  5.73172808] r -8.0
# Linear: 0.47427765 Angular: 0.39225248
# yes
# episode_count: 160 action [8.6653012 0.8202517] r -8.0
# Linear: 0.6173346 Angular: 0.76132166
# yes
# episode_count: 160 action [13.78656268 -1.4398706 ] r -8.0
# Linear: 0.27434874 Angular: 0.7474563
# yes
# episode_count: 160 action [10.21805048 -4.73107576] r -8.0
# Linear: 0.3902553 Angular: -0.87984717
# yes
# episode_count: 160 action [-4.89591867 12.70102501] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -0.71333694
# yes
# episode_count: 160 action [-7.13336945  7.13336945] r -8.0
# Linear: 0.0 Angular: -0.9231633
# yes
# episode_count: 160 action [-9.23163295  9.23163295] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.45275408
# yes
# episode_count: 160 action [ 4.5275408 -4.5275408] r -8.0
# Linear: 0.85016423 Angular: 0.626551
# yes
# episode_count: 160 action [14.76715207  2.23613262] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.29017377 Angular: 0.37492123
# yes
# episode_count: 160 action [ 6.65094972 -0.84747463] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 160 action [ 10. -10.] r -8.0
# Linear: 0.54293317 Angular: 1.0
# yes
# episode_count: 160 action [15.42933226 -4.57066834] r -8.0
# Linear: 0.06717641 Angular: 1.0
# yes
# episode_count: 160 action [10.67176461 -9.32823598] r -8.0
# Linear: 0.11892436 Angular: -0.86185455
# yes
# episode_count: 160 action [-7.42930174  9.80778933] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 160 action [-10.  10.]
r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.49147514 Angular: 0.93533534
# yes
# episode_count: 162 action [14.26810503 -4.43860203] r -8.0
# Linear: 0.0 Angular: 0.9828206
# yes
# episode_count: 162 action [ 9.8282057 -9.8282057] r -8.0
# Linear: 0.70128584 Angular: -1.0
# yes
# episode_count: 162 action [-2.98714161 17.01285839] r -8.0
# Linear: 0.2996807 Angular: -0.8393366
# yes
# episode_count: 162 action [-5.39655864 11.39017344] r -8.0
# Linear: 0.23518227 Angular: -1.0
# yes
# episode_count: 162 action [-7.64817715 12.35182285] r -8.0
# Linear: 0.12657234 Angular: -0.573786
# yes
# episode_count: 162 action [-4.4721368   7.00358391] r -8.0
# Linear: 0.58075106 Angular: -1.0
# yes
# episode_count: 162 action [-4.19248939 15.80751061] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.6454589
# yes
# episode_count: 162 action [ 6.45458877 -6.45458877] r -8.0
# Linear: 0.0 Angular: 0.27656788
# yes
# episode_count: 162 action [ 2.76567876 -2.76567876] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.3637906
# yes
# episode_count: 162 action [ 3.63790601 -3.63790601] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r 0.016650473625490214
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r 0.05581467556130537
# Linear: 0.6244779 Angular: -0.7167884
# yes
# episode_count: 162 action [-0.92310488 13.41266394] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.20784914 Angular: 1.0
# yes
# episode_count: 162 action [12.07849145 -7.92150855] r -8.0
# Linear: 0.13095458 Angular: 0.47613072
# yes
# episode_count: 162 action [ 6.07085288 -3.4517616 ] r -8.0
# Linear: 0.0 Angular: 0.6807563
# yes
# episode_count: 162 action [ 6.80756271 -6.80756271] r -8.0
# Linear: 0.0 Angular: -0.70792073
# yes
# episode_count: 162 action [-7.0792073  7.0792073] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r 0.050428227085008714
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r 0.0765905904111408
# Linear: 0.0 Angular: -0.9408101
# yes
# episode_count: 162 action [-9.40810084  9.40810084] r 0.1049249500964411
# Linear: 0.76296103 Angular: -1.0
# yes
# episode_count: 162 action [-2.3703897 17.6296103] r -8.0
# Linear: 0.6017775 Angular: 1.0
# yes
# episode_count: 162 action [16.01777554 -3.98222506] r -8.0
# Linear: 0.10241175 Angular: 1.0
# yes
# episode_count: 162 action [11.02411747 -8.97588253] r -8.0
# Linear: 0.0 Angular: 0.6311725
# yes
# episode_count: 162 action [ 6.31172478 -6.31172478] r -8.0
# Linear: 0.0 Angular: 0.8069021
# yes
# episode_count: 162 action [ 8.06902111 -8.06902111] r -8.0
# Linear: 0.097160175 Angular: 0.8217062
# yes
# episode_count: 162 action [ 9.18866336 -7.24546015] r -8.0
# Linear: 0.0 Angular: 0.30163452
# yes
# episode_count: 162 action [ 3.0163452 -3.0163452] r -8.0
# Linear: 0.0 Angular: -0.22078326
# yes
# episode_count: 162 action [-2.20783263  2.20783263] r -8.0
# Linear: 0.052231126 Angular: -1.0
# yes
# episode_count: 162 action [-9.47768867 10.52231073] r -8.0
# Linear: 0.09549386 Angular: -1.0
# yes
# episode_count: 162 action [-9.04506147 10.95493913] r -8.0
# Linear: 0.63258827 Angular: 0.060537938
# yes
# episode_count: 162 action [6.93126202 5.72050333] r -8.0
# Linear: 0.0 Angular: 0.7599257
# yes
# episode_count: 162 action [ 7.59925723 -7.59925723] r -8.0
# Linear: 0.1785901 Angular: 1.0
# yes
# episode_count: 162 action [11.78590059 -8.21409881] r -8.0
# Linear: 0.38492498 Angular: 0.75085497
# yes
# episode_count: 162 action [11.35779977 -3.65929991] r -8.0
# Linear: 0.4689169 Angular: 0.56348747
# yes
# episode_count: 162 action [10.32404423 -0.94570577] r -8.0
# Linear: 0.15275379 Angular: -0.5809622
# yes
# episode_count: 162 action [-4.28208411  7.33715951] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.07117599 Angular: -1.0
# yes
# episode_count: 162 action [-9.28824008 10.71176052] r -8.0
# Linear: 0.0 Angular: -0.8935274
# yes
# episode_count: 162 action [-8.93527389  8.93527389] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r 0.03606909313920159
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.9596422
# yes
# episode_count: 162 action [ 9.59642172 -9.59642172] r -8.0
# Linear: 0.0 Angular: 0.63149107
# yes
# episode_count: 162 action [ 6.31491065 -6.31491065] r -8.0
# Linear: 0.64229906 Angular: 1.0
# yes
# episode_count: 162 action [16.42299056 -3.57700944] r -8.0
# Linear: 0.1876195 Angular: 1.0
# yes
# episode_count: 162 action [11.87619448 -8.12380493] r -8.0
# Linear: 0.0 Angular: 0.35797822
# yes
# episode_count: 162 action [ 3.57978225 -3.57978225] r -8.0
# Linear: 0.0 Angular: -0.9082714
# yes
# episode_count: 162 action [-9.08271372  9.08271372] r -8.0
# Linear: 0.9354145 Angular: -1.0
# yes
# episode_count: 162 action [-0.64585507 19.35414553] r -8.0
# Linear: 0.0 Angular: -0.8430342
# yes
# episode_count: 162 action [-8.43034208  8.43034208] r -8.0
# Linear: 0.7345431 Angular: -0.80143434
# yes
# episode_count: 162 action [-0.66891253 15.35977364] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -0.6668192
# yes
# episode_count: 162 action [-6.66819215  6.66819215] r -8.0
# Linear: 0.0 Angular: 0.7889852
# yes
# episode_count: 162 action [ 7.88985193 -7.88985193] r 0.07949092021297677
# Linear: 0.09218503 Angular: 1.0
# yes
# episode_count: 162 action [10.9218502 -9.0781498] r 0.04359573689278751
# Linear: 0.17502913 Angular: 0.5044119
# yes
# episode_count: 162 action [ 6.79440975 -3.29382747] r 0.0011068805303660056
# Linear: 0.58414507 Angular: 0.97620964
# yes
# episode_count: 162 action [15.6035471  -3.92064571] r -8.0
# Linear: 0.0 Angular: 0.79799944
# yes
# episode_count: 162 action [ 7.97999442 -7.97999442] r -8.0
# Linear: 0.119919986 Angular: 1.0
# yes
# episode_count: 162 action [11.19920015 -8.80079985] r -8.0
# Linear: 0.0 Angular: -0.23438016
# yes
# episode_count: 162 action [-2.34380156  2.34380156] r -8.0
# Linear: 0.681418 Angular: -1.0
# yes
# episode_count: 162 action [-3.18581998 16.81417942] r -8.0
r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.66565657 Angular: 0.095139295
# yes
# episode_count: 162 action [7.60795832 5.70517302] r -8.0
# Linear: 0.70242494 Angular: -0.7375405
# yes
# episode_count: 162 action [-0.3511554  14.39965487] r -8.0
# Linear: 0.07589406 Angular: -0.27901965
# yes
# episode_count: 162 action [-2.03125596  3.54913712] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.22835049 Angular: -0.6725465
# yes
# episode_count: 162 action [-4.44196016  9.00897026] r -8.0
# Linear: 0.16943903 Angular: -1.0
# yes
# episode_count: 162 action [-8.30560982 11.69439077] r -8.0
# Linear: 0.0 Angular: 0.4063007
# yes
# episode_count: 162 action [ 4.06300694 -4.06300694] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.30898282 Angular: 0.7636123
# yes
# episode_count: 162 action [10.72595119 -4.54629451] r -8.0
# Linear: 0.0 Angular: 0.7260217
# yes
# episode_count: 162 action [ 7.26021707 -7.26021707] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.100669526 Angular: 1.0
# yes
# episode_count: 162 action [11.00669503 -8.99330497] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -0.618475
# yes
# episode_count: 162 action [-6.1847502  6.1847502] r -8.0
# Linear: 0.0 Angular: -0.36504
# yes
# episode_count: 162 action [-3.65040004  3.65040004] r -8.0
# Linear: 0.4945994 Angular: -0.73142487
# yes
# episode_count: 162 action [-2.36825466 12.2602427 ] r -8.0
# Linear: 0.1758256 Angular: -0.6392915
# yes
# episode_count: 162 action [-4.63465929  8.15117121] r -8.0
# Linear: 0.0 Angular: -0.7828475
# yes
# episode_count: 162 action [-7.82847524  7.82847524] r 0.030448028390694937
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r 0.04550962661173941
# Linear: 0.39073014 Angular: -0.5816196
# yes
# episode_count: 162 action [-1.90889478  9.72349763] r -8.0
# Linear: 0.0 Angular: 0.7893149
# yes
# episode_count: 162 action [ 7.89314926 -7.89314926] r -8.0
# Linear: 0.07856777 Angular: 0.9263887
# yes
# episode_count: 162 action [10.04956484 -8.47820878] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.0 Angular: 0.4605266
# yes
# episode_count: 162 action [ 4.60526586 -4.60526586] r -8.0
# Linear: 0.13066228 Angular: 0.74652714
# yes
# episode_count: 162 action [ 8.77189398 -6.15864873] r -8.0
# Linear: 0.5307182 Angular: 0.57922274
# yes
# episode_count: 162 action [11.09941006 -0.48504531] r -8.0
# Linear: 0.7815734 Angular: 1.0
# yes
# episode_count: 162 action [17.81573415 -2.18426585] r -8.0
# Linear: 0.3809536 Angular: 1.0
# yes
# episode_count: 162 action [13.8095355 -6.1904639] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.13264544 Angular: -1.0
# yes
# episode_count: 162 action [-8.67354572 11.32645488] r -8.0
# Linear: 0.52047247 Angular: -0.99369365
# yes
# episode_count: 162 action [-4.73221183 15.14166117] r -8.0
# Linear: 0.20742986 Angular: -1.0
# yes
# episode_count: 162 action [-7.92570114 12.07429886] r -8.0
# Linear: 0.0 Angular: -0.55745363
# yes
# episode_count: 162 action [-5.57453632  5.57453632] r -8.0
# Linear: 0.5066857 Angular: -1.0
# yes
# episode_count: 162 action [-4.93314326 15.06685734] r -8.0
# Linear: 0.697292 Angular: -0.68013114
# yes
# episode_count: 162 action [ 0.17160833 13.77423048] r -8.0
# Linear: 0.061158765 Angular: -0.05173176
# yes
# episode_count: 162 action [0.09427004 1.12890527] r -8.0
# Linear: 0.0 Angular: -0.06978753
# yes
# episode_count: 162 action [-0.69787532  0.69787532] r -8.0
# Linear: 0.0 Angular: 0.3841295
# yes
# episode_count: 162 action [ 3.84129494 -3.84129494] r -8.0
# Linear: 0.026662195 Angular: 0.8223869
# yes
# episode_count: 162 action [ 8.49049091 -7.9572475 ] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.37102044 Angular: 0.76337457
# yes
# episode_count: 162 action [11.34395003 -3.92354131] r -8.0
# Linear: 0.0 Angular: -1.0
# yes
# episode_count: 162 action [-10.  10.] r -8.0
# Linear: 0.30704325 Angular: -0.71407884
# yes
# episode_count: 162 action [-4.07035589 10.21122098] r -8.0
# Linear: 0.35002312 Angular: -1.0
# yes
# episode_count: 162 action [-6.4997685 13.5002315] r -8.0
# Linear: 0.42945772 Angular: -0.50605226
# yes
# episode_count: 162 action [-0.76594532  9.3550998 ] r -8.0
# Linear: 0.07865403 Angular: 0.4120226
# yes
# episode_count: 162 action [ 4.90676612 -3.3336857 ] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# Linear: 0.3028721 Angular: 1.0
# yes
# episode_count: 162 action [13.02872062 -6.97127938] r -8.0
# Linear: 0.0 Angular: -0.9695035
# yes
# episode_count: 162 action [-9.69503522  9.69503522] r -8.0
# Linear: 0.53256774 Angular: -1.0
# yes
# episode_count: 162 action [-4.67432261 15.32567739] r -8.0
# Linear: 0.0 Angular: -0.9757831
# yes
# episode_count: 162 action [-9.7578311  9.7578311] r -8.0
# Linear: 0.38424766 Angular: -1.0
# yes
# episode_count: 162 action [-6.15752339 13.84247661] r -8.0
# Linear: 0.10543604 Angular: 0.14942604
# yes
# episode_count: 162 action [ 2.5486207  -0.43990001] r -8.0
# Linear: 0.0 Angular: 1.0
# yes
# episode_count: 162 action [ 10. -10.] r -8.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-72c97c35a22a> in <module>()
#      27                 #    #print('aa', action)
#      28                 #else:
# ---> 29                 action = trainer.get_exploration_action(state)
#      30                 #    #print('aa',action)
#      31                 action[0] = np.clip(np.random.normal(action[0], var_v), 0., ACTION_V_MAX)
#
# <ipython-input-5-e30437dfca7d> in get_exploration_action(self, state)
#      38     def get_exploration_action(self, state):
#      39         state = torch.from_numpy(state)
# ---> 40         action = self.actor.forward(state).detach()
#      41         #noise = self.noise.sample()
#      42         #print('noisea', noise)
#
# <ipython-input-4-96e4c75016c3> in forward(self, state)
#      84     def forward(self, state):
#      85         x = torch.relu(self.fa1(state))
# ---> 86         x = torch.relu(self.fa2(x))
#      87         action = self.fa3(x)
#      88         if state.shape == torch.Size([14]):
#
# KeyboardInterrupt:
